# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayma-sudo/senulationlab/blob/main/sayma-1060T_Day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy.stats as stats #new library
import matplotlib.pyplot as plt

# %%
# Step 1: Define the dataset (observed sample)
data = np.array([65, 72, 68, 75, 80, 62, 71, 78, 74, 69])  # Exam scores of 10 students

# Step 2: Define the population mean (hypothesized mean)
population_mean = 70  # Null Hypothesis (H₀): The average class score is 70

# Step 3: Perform the one-sample t-test
t_statistic, p_value = stats.ttest_1samp(data, population_mean)
#$ci = stats.t.interval(0.95, df=len(data)-1, loc=np.mean(data), scale=stats.sem(data))

# Step 4: Display the results
print(f'Sample Mean: {np.mean(data):.2f}')
print(f'Hypothesized Population Mean: {population_mean:.2f}')
print(f't-Statistic: {t_statistic:.2f}')
print(f'Degrees of Freedom: {len(data) - 1}')
print(f'p-Value: {p_value:.4f}')
#print(f'Confidence Interval: [{ci[0]:.2f}, {ci[1]:.2f}]')
# Out:
# Sample Mean: 71.40
# Hypothesized Population Mean: 70.00
# t-Statistic: 0.79
# Degrees of Freedom: 9
# p-Value: 0.4512

# %%
# Step 6: Visualize the data
plt.figure()
plt.bar(1, np.mean(data), color="skyblue", label='Sample Mean')
plt.errorbar(1, np.mean(data), yerr=np.std(data), fmt='k', linewidth=1.5)
plt.axhline(y=population_mean, color='r', linestyle='--', linewidth=1.5, label='Hypothesized Mean')
plt.title('Sample Mean vs Hypothesized Mean')
plt.xlim(0.5,1.5)
plt.xlabel('Sample')
plt.ylabel('Mean Value')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Student Work
# •	Data: [5.2, 5.4, 5.1, 5.6, 5.3, 5.8]<br>
# •	Hypothesized mean: 5.5 <br>
# •	Tasks:<br>
# o	Calculate the t-statistic and p-value.<br>
# o	Interpret and visualize the result at a 0.05 significance level.<br>

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Data
data = np.array([5.2, 5.4, 5.1, 5.6, 5.3, 5.8])
hypothesized_mean = 5.5
alpha = 0.05

# One-sample t-test
t_statistic, p_value = stats.ttest_1samp(data, hypothesized_mean)

print(f"t-Statistic: {t_statistic:.2f}")
print(f"p-Value: {p_value:.4f}")

# Interpretation
if p_value < alpha:
    print(f"Reject the null hypothesis. The mean is significantly different from {hypothesized_mean}.")
else:
    print(f"Fail to reject the null hypothesis. The mean is not significantly different from {hypothesized_mean}.")

# Visualization
plt.figure(figsize=(6,5))
plt.bar(1, np.mean(data), color="skyblue", label="Sample Mean")
plt.errorbar(1, np.mean(data), yerr=np.std(data, ddof=1), fmt='k', linewidth=1.5, capsize=5)
plt.axhline(y=hypothesized_mean, color="red", linestyle="--", linewidth=1.5, label=f"Hypothesized Mean ({hypothesized_mean})")
plt.title("Sample Mean vs Hypothesized Mean")
plt.xlim(0.5, 1.5)
plt.xlabel("Sample")
plt.ylabel("Mean Value")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()
# Out:
# t-Statistic: -0.94
# p-Value: 0.3907
# Fail to reject the null hypothesis. The mean is not significantly different from 5.5.
